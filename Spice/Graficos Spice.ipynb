# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Graficos de los circuitos de Spice     --------------------------------------

VDQ = 0.510417
IDQ = 0.00029454E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_Diodo\\Diodo.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VD = l.get_data('V(VD)')
ID = l.get_data('I(D1)')
ID = (ID) * 1E+3
#------------------------------------------------


#Set mplt and min Voltages and currents
V_upper_limit = 0.58
V_lower_limit = -0.15
I_upper_limit = 0.85
I_lower_limit = -0.05

fig = plt.figure(figsize=(6, 4))

#Current plot
plt.xlabel("$V_D \ [V]$")
plt.ylabel("$I_D \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VDQ,VDQ], [IDQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VDQ], [IDQ, IDQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VDQ, IDQ, color='red', s = 30)
plt.scatter(VDQ, I_lower_limit, color='black', s = 1, label = '$V_{DQ} = 0,510 \ V$')
plt.scatter(V_lower_limit, IDQ, color='black', s = 1, label = '$I_{DQ} = 294,54 \ uA$')
plt.annotate(r"$Q$", xy=(VDQ, IDQ), xytext=(-7, 7),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()

plt.plot(VD , ID, 'b-')
plt.legend(fontsize = 16)

#plt.savefig('Grafico Circuito Diodo.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico BJT Curva de Entrada     --------------------------------------
VBEQ = 0.600717
ICQ = 0.000238655E+6

#------------Load the signals from the .raw file
raw_file = 'Circuito_BJT\\Circuito_BJT_Curva_Entrada.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VBE = l.get_data('V(vbe)')
IC = l.get_data('I(Rc)')
IC = (IC) * 1E+6
#------------------------------------------------

chargeTime = np.linspace(0, 250, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 0.9
V_lower_limit = -0.5
I_upper_limit = 350
I_lower_limit = -5

fig = plt.figure(figsize=(7, 5))
fig.subplots_adjust(hspace=0.5)

#Current plot
plt.xlabel("$V_{BE}\ [V]$")
plt.ylabel("$I_C \ [uA]$")

#---------      Anotaciones     --------------
plt.plot([VBEQ,VBEQ], [ICQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VBEQ], [ICQ, ICQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VBEQ, ICQ, color='red', s = 30)
plt.scatter(VBEQ, I_lower_limit, color='black', s = 1, label = '$V_{BEQ} = 0,6 \ V$')
plt.scatter(V_lower_limit, ICQ, color='black', s = 1, label = '$I_{CQ} = 238,65 \ uA$')
plt.annotate(r"$Q$", xy=(VBEQ, ICQ), xytext=(-9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VBE , IC, 'b-')

#plt.savefig('Grafico Curva de Entrada BJT.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico BJT Curva de Salida     --------------------------------------
VCEQ = 1.42017
ICQ = 0.000238655E+6

#------------Load the signals from the .raw file
raw_file = 'Circuito_BJT\\Circuito_BJT_Curva_Salida.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VCE = l.get_data('V(vce)')
IC = l.get_data('I(Rc)')
IC = (IC) * 1E+6
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 3
V_lower_limit = 0
I_upper_limit = 300
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{CE}\ [V]$")
plt.ylabel("$I_C \ [uA]$")

#---------      Anotaciones     --------------
plt.plot([VCEQ,VCEQ], [ICQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VCEQ], [ICQ, ICQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VCEQ, ICQ, color='red', s = 30)
plt.scatter(VCEQ, I_lower_limit, color='black', s = 1, label = '$V_{CEQ} = 1,42 \ V$')
plt.scatter(V_lower_limit, ICQ, color='black', s = 1, label = '$I_{CQ} = 238,65 \ uA$')
plt.annotate(r"$Q$", xy=(VCEQ, ICQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VCE , IC, 'b-')

#plt.savefig('Grafico Curva Salida BJT.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico MOSFET Enrich Curva de Entrada     --------------------------------------
VGSQ = 1.67308
IDSQ = 0.00106823E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_MOSFET_Enrich\\Circuito_MOSFET_Enrich_Curva_Entrada.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VGS = l.get_data('V(vgs)')
IDS = l.get_data('I(Rd)')
IDS = (IDS) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 2
V_lower_limit = 0
I_upper_limit = 2.5
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{GS}\ [V]$")
plt.ylabel("$I_{DS} \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VGSQ,VGSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VGSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VGSQ, IDSQ, color='red', s = 30)
plt.scatter(VGSQ, I_lower_limit, color='black', s = 1, label = '$V_{GSQ} = 1,673 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DSQ} = 1,068 \ mA$')
plt.annotate(r"$Q$", xy=(VGSQ, IDSQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VGS , IDS, 'b-')

#plt.savefig('Grafico Curva Entrada MOSFET Enrich.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico MOSFET Enrich Curva de Salida     --------------------------------------
VDSQ = 4.65883
IDSQ = 0.00106823E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_MOSFET_Enrich\\Circuito_MOSFET_Enrich_Curva_Salida.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VDS = l.get_data('V(vds)')
IDS = l.get_data('I(Rd)')
IDS = (IDS) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 5
V_lower_limit = 0
I_upper_limit = 1.2
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{GS}\ [V]$")
plt.ylabel("$I_{DS} \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VDSQ,VDSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VDSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VDSQ, IDSQ, color='red', s = 30)
plt.scatter(VDSQ, I_lower_limit, color='black', s = 1, label = '$V_{DSQ} = 4.659 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DSQ} = 1,068 \ mA$')
plt.annotate(r"$Q$", xy=(VDSQ, IDSQ), xytext=(-9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VDS , IDS, 'b-')

#plt.savefig('Grafico Curva Salida MOSFET Enrich.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico MOSFET Vac Curva de Entrada     --------------------------------------
VGSQ = -0.3
IDSQ = 0.00104665E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_MOS_VAC/simvgsconlabel.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VGS = l.get_data('v2')
IDS = l.get_data('I(R1)')
IDS = (IDS) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 3
V_lower_limit = -3
I_upper_limit = 1.3
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{GS}\ [V]$")
plt.ylabel("$I_{DS} \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VGSQ,VGSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VGSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VGSQ, IDSQ, color='red', s = 30)
plt.scatter(VGSQ, I_lower_limit, color='black', s = 1, label = '$V_{GSQ} = 0,3 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DSQ} = 1,04 \ mA$')
plt.annotate(r"$Q$", xy=(VGSQ, IDSQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VGS , IDS, 'b-')

plt.savefig('Grafico Curva Entrada MOSFET Vac.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico MOSFET Vaciamiento Curva de Salida     --------------------------------------
VDSQ = 1.10347
IDSQ = 0.00104665E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_MOS_VAC/simvdsconlabel.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VDS = l.get_data('V(vout)')
ID = l.get_data('I(R1)')
ID = (ID) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 5
V_lower_limit = 0
I_upper_limit = 2
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{DS}\ [V]$")
plt.ylabel("$I_D \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VDSQ,VDSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VDSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VDSQ, IDSQ, color='red', s = 30)
plt.scatter(VDSQ, I_lower_limit, color='black', s = 1, label = '$V_{DSQ} = 1,1 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DQ} = 1,04 \ mA$')
plt.annotate(r"$Q$", xy=(VDSQ, IDSQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VDS , ID, 'b-')

plt.savefig('Grafico Curva Salida MOSFET VAC.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico JFET Curva de Entrada     --------------------------------------
VGSQ = -0.665
IDSQ = 0.00710883E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_JFET/simvgslabel.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VGS = l.get_data('V(n002)')
IDS = l.get_data('I(R1)')
IDS = (IDS) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 0
V_lower_limit = -4
I_upper_limit = 10
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{GS}\ [V]$")
plt.ylabel("$I_{DS} \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VGSQ,VGSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VGSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VGSQ, IDSQ, color='red', s = 30)
plt.scatter(VGSQ, I_lower_limit, color='black', s = 1, label = '$V_{GSQ} = -0.6 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DSQ} = 7,1 \ mA$')
plt.annotate(r"$Q$", xy=(VGSQ, IDSQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VGS , IDS, 'b-')

plt.savefig('Grafico Curva Entrada JFET.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico JFET Curva de Salida     --------------------------------------
VDSQ = 2.67791
IDSQ = 0.00710883E+3

#------------Load the signals from the .raw file
raw_file = 'Circuito_JFET/simvdslabel.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VDS = l.get_data('V(vout)')
IDS = l.get_data('I(R1)')
IDS = (IDS) * 1E+3
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
V_upper_limit = 5
V_lower_limit = 0
I_upper_limit = 10
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$V_{DS}\ [V]$")
plt.ylabel("$I_{DS} \ [mA]$")

#---------      Anotaciones     --------------
plt.plot([VDSQ,VDSQ], [IDSQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VDSQ], [IDSQ, IDSQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VDSQ, IDSQ, color='red', s = 30)
plt.scatter(VDSQ, I_lower_limit, color='black', s = 1, label = '$V_{DSQ} = 2,7 \ V$')
plt.scatter(V_lower_limit, IDSQ, color='black', s = 1, label = '$I_{DSQ} = 7,1 \ mA$')
plt.annotate(r"$Q$", xy=(VDSQ, IDSQ), xytext=(9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot(VDS , IDS, 'b-')

plt.savefig('Grafico Curva Salida JFET.pdf', format='pdf')
plt.show()

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico BJT Pequeña señal     --------------------------------------

ICQ = 0.000238655E+6

#------------Load the signals from the .raw file
raw_file5mV = 'Circuito_BJT/Circuito_BJT_Transitorio5mV.raw'
l5 = ltspice.Ltspice(raw_file5mV) 
raw_file8mV = 'Circuito_BJT/Circuito_BJT_Transitorio8mV.raw'
l8 = ltspice.Ltspice(raw_file8mV) 
raw_file9mV = 'Circuito_BJT/Circuito_BJT_Transitorio9mV.raw'
l9 = ltspice.Ltspice(raw_file9mV) 
raw_file10mV = 'Circuito_BJT/Circuito_BJT_Transitorio10mV.raw'
l10 = ltspice.Ltspice(raw_file10mV) 
# Make sure that the .raw file is located in the correct path
l5.parse()
l8.parse()
l9.parse()
l10.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
time5mV = l5.get_time()
time5mV = (time5mV) * 1E+3
IC_5mV = l5.get_data('I(Rc)')
IC_5mV = (IC_5mV) * 1E+6
time8mV = l8.get_time()
time8mV = (time8mV) * 1E+3
IC_8mV = l8.get_data('I(Rc)')
IC_8mV = (IC_8mV) * 1E+6
time9mV = l9.get_time()
time9mV = (time9mV) * 1E+3
IC_9mV = l9.get_data('I(Rc)')
IC_9mV = (IC_9mV) * 1E+6
time10mV = l10.get_time()
time10mV = (time10mV) * 1E+3
IC_10mV = l10.get_data('I(Rc)')
IC_10mV = (IC_10mV) * 1E+6
#------------------------------------------------

chargeTime = np.linspace(0, 450, 1000)


#Set mplt and min Voltages and currents
time_upper_limit = 2
time_lower_limit = 0
I_upper_limit = 380
I_lower_limit = 120

fig = plt.figure(figsize=(7, 5))

#Current plot
plt.xlabel("$t \ [mS]$")
plt.ylabel("$i_{C} \ [uA]$")

plt.xlim(time_lower_limit, time_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()
plt.legend(fontsize = 16)

plt.plot([time_lower_limit,time_upper_limit], [ICQ, ICQ], linestyle = '--', linewidth = 1.5,  color = 'orange')
plt.annotate(r"$I_{CQ}$", xy=(time_lower_limit, ICQ), xytext=(0, 0),textcoords='offset points', va='top', ha = 'right', fontsize = 15, color = 'orange')
plt.plot(time5mV , IC_5mV, 'b-', label = '$v_{be} = 5mV$')
plt.plot(time8mV , IC_8mV, 'g-', label = '$v_{be} = 8mV$')
plt.plot(time9mV , IC_9mV, 'r-', label = '$v_{be} = 9mV$')
plt.plot(time10mV , IC_10mV, 'm-', label = '$v_{be} = 10mV$')
plt.legend(fontsize = 13)

#plt.savefig('Grafico Pequeña señal BJT.pdf', format='pdf')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import os

# ----------------------------     Grafico BJT Curva de Entrada     --------------------------------------
VBEQ = 0.600717
ICQ = 0.000238655E+6

#------------Load the signals from the .raw file
raw_file = 'Circuito_BJT\\Circuito_BJT_Curva_Entrada.raw'
l = ltspice.Ltspice(raw_file) 
# Make sure that the .raw file is located in the correct path
l.parse()
#-----------------------------------------------


#----------------------------Obtain basic signals         
VBE = l.get_data('V(vbe)')
IC = l.get_data('I(Rc)')
IC = (IC) * 1E+6
#------------------------------------------------

#Set mplt and min Voltages and currents
V_upper_limit = 0.8
V_lower_limit = 0.4
I_upper_limit = 350
I_lower_limit = 0

fig = plt.figure(figsize=(7, 5))
fig.subplots_adjust(hspace=0.5)

#Current plot
plt.xlabel("$V_{BE}\ [V]$")
plt.ylabel("$I_C \ [uA]$")

#---------      Anotaciones     --------------
plt.plot([VBEQ,VBEQ], [ICQ, I_lower_limit], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.plot([V_lower_limit,VBEQ], [ICQ, ICQ], linestyle = '--', linewidth = 1.5,  color = 'black')
plt.scatter(VBEQ, ICQ, color='red', s = 30)
plt.annotate(r"$Q$", xy=(VBEQ, ICQ), xytext=(-9, -15),textcoords='offset points', ha='center', fontsize = 15, color = 'red')

plt.fill_between(VBE[2591:2611], IC[2591:2611], color='green', alpha=0.5)
plt.plot([VBEQ - 0.009, VBEQ - 0.009], [I_lower_limit, IC[2591]], linestyle = '--', linewidth = 1.5,  color = 'green')
plt.annotate(r"$V_{BEQ} - 9mV}$", xy=(VBEQ - 0.009, 25), xytext=(0, 0),textcoords='offset points', ha='right', fontsize = 13, color = 'green')
plt.plot([VBEQ + 0.009, VBEQ + 0.009], [I_lower_limit, IC[2611]], linestyle = '--', linewidth = 1.5,  color = 'green')
plt.annotate(r"$V_{BEQ} + 9mV}$", xy=(VBEQ + 0.009, 25), xytext=(0, 0),textcoords='offset points', ha='left', fontsize = 13, color = 'green')

plt.xlim(V_lower_limit, V_upper_limit)
plt.ylim(I_lower_limit, I_upper_limit)
plt.grid()

plt.plot(VBE , IC, 'b-')

#plt.savefig('Grafico Validez Pequeña señal.pdf', format='pdf')
plt.show()
